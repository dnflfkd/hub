# %% [markdown]
# <a href="https://colab.research.google.com/github/dnflfkd/hub/blob/main/git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('123')
# Out:
# 123
